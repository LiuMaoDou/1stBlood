# %%
from pathlib import Path

# %%
import os

# %% [markdown]
# ## 链接文件名 --> `/`

# %%
ap = Path('/Users/liumaodou')
bp = Path('Downloads') # Downloads前面如果有/就会不成功

# %%
cp = ap / bp

# %%
cp
# Out:
# PosixPath('/Users/liumaodou/Downloads')

# %% [markdown]
# ## 当前文件位置 --> `Path.cwd()`

# %%
Path.cwd()
# Out:
# PosixPath('/Users/liumaodou')

# %% [markdown]
# ## Home文件夹 --> `Path.home()`

# %%
Path.home()
# Out:
# PosixPath('/Users/liumaodou')

# %% [markdown]
# ## 创建文件夹 --> `Path().mkdir()`

# %%
Path('/Users/liumaodou/Downloads/test0702').mkdir()

# %%
Path('/Users/liumaodou/Downloads/test0702').is_dir()
# Out:
# True

# %% [markdown]
# ---

# %%
pathfile = r'/Users/liumaodou/Downloads/USG6000V.zip'

# %% [markdown]
# ## 提取文件名（不包括文件夹名）

# %%
os.path.basename(pathfile)
# Out:
# 'USG6000V.zip'

# %% [markdown]
# ## 提取文件夹名（不包括文件名）

# %%
os.path.dirname(pathfile)
# Out:
# '/Users/liumaodou/Downloads'

# %% [markdown]
# ## Path提取
# ![09fig04.jpg](attachment:09fig04.jpg)

# %%
p = Path(pathfile)

# %%
p.anchor
# Out:
# '/'

# %%
p.parent
# Out:
# PosixPath('/Users/liumaodou/Downloads')

# %%
p.stem
# Out:
# 'USG6000V'

# %%
p.drive
# Out:
# ''

# %%
p.suffix
# Out:
# '.zip'

# %%
p.name
# Out:
# 'USG6000V.zip'

# %% [markdown]
# ## 文件夹和文件名详细拆分

# %%
pathfile.split(os.sep)
# Out:
# ['', 'Users', 'liumaodou', 'Downloads', 'USG6000V.zip']

# %% [markdown]
# ## Glob Patterns --> `p.glob()`

# %%
p1 = r'/Users/liumaodou/Downloads'

# %%
p = Path(p1)

# %%
p.glob('*') #glob里面可以填写正则表达式过滤
# Out:
# <generator object Path.glob at 0x7fe80099ff90>

# %%
p_list = list(p.glob('*'))

# %%
p_list
# Out:
# [PosixPath('/Users/liumaodou/Downloads/First_Book.ipynb'),
#  PosixPath('/Users/liumaodou/Downloads/CloudMetro V100R019C10 E2E SR-MPLS 5G承载解决方案LLD设计指导书 01.docx')]

# %%
p_zip = p.glob('*.zip')

# %%
list(p_zip)
# Out:
# [PosixPath('/Users/liumaodou/Downloads/ensp.zip'),
#  PosixPath('/Users/liumaodou/Downloads/CloudMetro V100R019C10 E2E SR-MPLS 5G承载解决方案LLD设计指导书 01(docx).zip')]

# %% [markdown]
# ## 验证文件夹，文件 --> `p.existes(), p.is_file(), p.is_dir()`

# %%
file = Path(r'/Users/liumaodou/Downloads/ensp.zip')
fileD = Path(r'/Users/liumaodou/Downloads/')

# %%
file.exists()
# Out:
# True

# %%
fileD.exists()
# Out:
# True

# %%
file.is_file()
# Out:
# True

# %%
fileD.is_file()
# Out:
# False

# %%
file.is_dir()
# Out:
# False

# %%
fileD.is_dir()
# Out:
# True

# %% [markdown]
# ---

# %% [markdown]
# ## 读写文件

# %%
txt_file = r'/Users/liumaodou/Documents/TXT0702'

# %%
content = open(txt_file) #默认是'r'模式

# %%
content.read()
# Out:
# 'Reading the Contents of FilesNow that you have a File object, \nyou can start reading from it. \nIf you want to read the entire contents of a file as a string value, \nuse the File object’s read() method. \nLet’s continue with the hello.txt File object you stored in helloFile. \nEnter the following into the interactive shell:'

# %%
content.close()

# %%
content = open(txt_file)

# %%
content.readlines()
# Out:
# ['Reading the Contents of FilesNow that you have a File object, \n',
#  'you can start reading from it. \n',
#  'If you want to read the entire contents of a file as a string value, \n',
#  'use the File object’s read() method. \n',
#  'Let’s continue with the hello.txt File object you stored in helloFile. \n',
#  'Enter the following into the interactive shell:']

# %%
content.close()

# %%
txt_file2 = r'/Users/liumaodou/Documents/TEST-0702.txt'

# %%
content = open(txt_file2,'w') # 还有个'a' mode，追加模式

# %%
content.write("123")
# Out:
# 3

# %%
content.close()
